# %%
import pandas as pd

# %%
naruto = pd.read_html('https://en.wikipedia.org/wiki/Naruto_(season_1)')

# %%
len(naruto)
# Out:
# 5

# %%
naruto[1]
# Out:
#                                            No. overall  \
# 0                                                    1
# 1    Naruto Uzumaki is a twelve-year-old ninja livi...
# 2                                                    2
# 3    While Naruto gets into an argument with Hiruze...
# 4                                                    3
# ..                                                 ...
# 109  Sakura visits the hospital to see Sasuke, but ...
# 110                                                 56
# 111  Jiraiya realizes that Naruto's training is tak...
# 112                                                 57
# 113  The giant toad, revealed to be named Gamabunta...
#
#                                          No. in season  \
# 0                                                    1
# 1    Naruto Uzumaki is a twelve-year-old ninja livi...
# 2                                                    2
# 3    While Naruto gets into an argument with Hiruze...
# ...
